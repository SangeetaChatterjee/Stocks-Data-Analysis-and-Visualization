# %% [markdown]
# <a href="https://colab.research.google.com/github/SangeetaChatterjee/Stocks-Data-Analysis-and-Visualization/blob/main/Finance_101_Portfolio_Assets_Allocation_and_Statistical_Data_Analysis_Skeleton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TASK #1: PROJECT OVERVIEW AND ASSET TYPES

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1TEVVCFWQD8F5mlC7FzD-JM2y54ivYZHT)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1Z253Wmij7HCEHqPsMdEI56qYqASRrsjn)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=10XxwtKY2qEiNAdTkqNXKhNFZrWvwwKbN)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1SfBtfOoDigo4ofEvPAwIojqGHpMojL5S)

# %% [markdown]
# Links:
# - https://www.bankofcanada.ca/rates/interest-rates/canadian-bonds/
# - https://ca.finance.yahoo.com/quote/AAPL?p=AAPL&.tsrc=fin-tre-srch
# - https://investor.vanguard.com/etf/profile/performance/voo
# - https://grow.acorns.com/warren-buffett-index-funds/

# %% [markdown]
# # TASK #2: IMPORT LIBRARIES & DATASETS AND PERFORM DATA VISUALIZATION

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import plotly.express as px
from copy import copy
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np  
import plotly.figure_factory as ff
import plotly.graph_objects as go

# %%
# Read the stock data file
stock_df = pd.read_csv('/content/drive/MyDrive/Python_Colab/Financial_Analysis/Part 2. Financial Analysis in Python/stock.csv')

# %%
# Sort the data based on Date
stock_df = stock_df.sort_values(by = ['Date'])
stock_df
# Out:
#             Date        AAPL          BA  ...         TSLA         GOOG        sp500
# 0     2012-01-12   60.198570   75.510002  ...    28.250000   313.644379  1295.500000
# 1     2012-01-13   59.972858   74.599998  ...    22.790001   311.328064  1289.089966
# 2     2012-01-17   60.671429   75.239998  ...    26.600000   313.116364  1293.670044
# 3     2012-01-18   61.301430   75.059998  ...    26.809999   315.273285  1308.040039
# 4     2012-01-19   61.107143   75.559998  ...    26.760000   318.590851  1314.500000
# ...          ...         ...         ...  ...          ...          ...          ...
# 2154  2020-08-05  440.250000  174.279999  ...  1485.020020  1473.609985  3327.770020
# 2155  2020-08-06  455.609985  172.199997  ...  1489.579956  1500.099976  3349.159912
# 2156  2020-08-07  444.450012  170.020004  ...  1452.709961  1494.489990  3351.280029
# 2157  2020-08-10  450.910004  179.410004  ...  1418.569946  1496.099976  3360.469971
# 2158  2020-08-11  437.500000  180.130005  ...  1374.390015  1480.319946  3333.689941
#
# [2159 rows x 10 columns]

# %% [markdown]
# **MINI CHALLENGE #1:**
# - **Use Plotly express to visualize raw stock data and normalized ones**

# %%
def plot_DataRa(da,title):
  fig = px.line(title= title)
  for i in da.columns[1:]:
    fig.add_scatter(x= da['Date'] , y=da[i] , name =i)
  fig.show()
   
def data_normalize(df):
  cop = df.copy()
  for i in cop.columns[1:]:
    cop[i] = cop[i]/cop[i][0] 
  return cop

plot_DataRa(stock_df,"NORMAL")
plot_DataRa(data_normalize(stock_df),"NORMALIZED")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9bee0031-8d7c-48ce-9062-0146ac7b8ecd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9bee0031-8d7c-48ce-9062-0146ac7b8ecd")) {
#                     Plotly.newPlot(
#                         '9bee0031-8d7c-48ce-9062-0146ac7b8ecd',
#                         [{"name": "AAPL", "type": "scatter", "x": ["2012-01-12", "2012-01-13", "2012-01-17", "2012-01-18", "2012-01-19", "2012-01-20", "2012-01-23", "2012-01-24", "2012-01-25", "2012-01-26", "2012-01-27", "2012-01-30", "2012-01-31", "2012-02-01", "2012-02-02", "2012-02-03", "2012-02-06", "2012-02-07", "2012-02-08", "2012-02-09", "2012-02-10", "2012-02-13", "2012-02-14", "2012-02-15", "2012-02-16", "2012-02-17", "2012-02-21", "2012-02-22", "2012-02-23", "2012-02-24", "2012-02-27", "2012-02-28", "2012-02-29", "2012-03-01", "2012-03-02", "2012-03-05", "2012-03-06", "2012-03-07", "2012-03-08", "2012-03-09", "2012-03-12", "2012-03-13", "2012-03-14", "2012-03-15", "2012-03-16", "2012-03-19", "2012-03-20", "2012-03-21", "2012-03-22", "2012-03-23", "2012-03-26", "2012-03-27", "2012-03-28", "2012-03-29", "2012-03-30", "2012-04-02", "2012-04-03", "2012-04-04", "2012-04-05", "2012-04-09", "2012-04-10", "2012-04-11", "2012-04-12", "2012-04-13", "2012-04-16", "2012-04-17", "2012-04-18", "2012-04-19", "2012-04-20", "2012-04-23", "2012-04-24", "2012-04-25", "2012-04-26", "2012-04-27", "2012-04-30", "2012-05-01", "2012-05-02", "2012-05-03", "2012-05-04", "2012-05-07", "2012-05-08", "2012-05-09", "2012-05-10", "2012-05-11", "2012-05-14", "2012-05-15", "2012-05-16", "2012-05-17", "2012-05-18", "2012-05-21", "2012-05-22", "2012-05-23", "2012-05-24", "2012-05-25", "2012-05-29", "2012-05-30", "2012-05-31", "2012-06-01", "2012-06-04", "2012-06-05", "2012-06-06", "2012-06-07", "2012-06-08", "2012-06-11", "2012-06-12", "2012-06-13", "2012-06-14", "2012-06-15", "2012-06-18", "2012-06-19", "2012-06-20", "2012-06-21", "2012-06-22", "2012-06-25", "2012-06-26", "2012-06-27", "2012-06-28", "2012-06-29", "2012-07-02", "2012-07-03", "2012-07-05", "2012-07-06", "2012-07-09", "2012-07-10", "2012-07-11", "2012-07-12", "2012-07-13", "2012-07-16", "2012-07-17", "2012-07-18", "2012-07-19", "2012-07-20", "2012-07-23", "2012-07-24", "2012-07-25", "2012-07-26", "2012-07-27", "2012-07-30", "2012-07-31", "2012-08-01", "2012-08-02", "2012-08-03", "2012-08-06", "2012-08-07", "2012-08-08", "2012-08-09", "2012-08-10", "2012-08-13", "2012-08-14", "2012-08-15", "2012-08-16", "2012-08-17", "2012-08-20", "2012-08-21", "2012-08-22", "2012-08-23", "2012-08-24", "2012-08-27", "2012-08-28", "2012-08-29", "2012-08-30", "2012-08-31", "2012-09-04", "2012-09-05", "2012-09-06", "2012-09-07", "2012-09-10", "2012-09-11", "2012-09-12", "2012-09-13", "2012-09-14", "2012-09-17", "2012-09-18", "2012-09-19", "2012-09-20", "2012-09-21", "2012-09-24", "2012-09-25", "2012-09-26", "2012-09-27", "2012-09-28", "2012-10-01", "2012-10-02", "2012-10-03", "2012-10-04", "2012-10-05", "2012-10-08", "2012-10-09", "2012-10-10", "2012-10-11", "2012-10-12", "2012-10-15", "2012-10-16", "2012-10-17", "2012-10-18", "2012-10-19", "2012-10-22", "2012-10-23", "2012-10-24", "2012-10-25", "2012-10-26", "2012-10-31", "2012-11-01", "2012-11-02", "2012-11-05", "2012-11-06", "2012-11-07", "2012-11-08", "2012-11-09", "2012-11-12", "2012-11-13", "2012-11-14", "2012-11-15", "2012-11-16", "2012-11-19", "2012-11-20", "2012-11-21", "2012-11-23", "2012-11-26", "2012-11-27", "2012-11-28", "2012-11-29", "2012-11-30", "2012-12-03", "2012-12-04", "2012-12-05", "2012-12-06", "2012-12-07", "2012-12-10", "2012-12-11", "2012-12-12", "2012-12-13", "2012-12-14", "2012-12-17", "2012-12-18", "2012-12-19", "2012-12-20", "2012-12-21", "2012-12-24", "2012-12-26", "2012-12-27", "2012-12-28", "2012-12-31", "2013-01-02", "2013-01-03", "2013-01-04", "2013-01-07", "2013-01-08", "2013-01-09", "2013-01-10", "2013-01-11", "2013-01-14", "2013-01-15", "2013-01-16", "2013-01-17", "2013-01-18", "2013-01-22", "2013-01-23", "2013-01-24", "2013-01-25", "2013-01-28", "2013-01-29", "2013-01-30", "2013-01-31", "2013-02-01", "2013-02-04", "2013-02-05", "2013-02-06", "2013-02-07", "2013-02-08", "2013-02-11", "2013-02-12", "2013-02-13", "2013-02-14", "2013-02-15", "2013-02-19", "2013-02-20", "2013-02-21", "2013-02-22", "2013-02-25", "2013-02-26", ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="66562625-e420-4d11-8cf9-907d95c49114" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("66562625-e420-4d11-8cf9-907d95c49114")) {
#                     Plotly.newPlot(
#                         '66562625-e420-4d11-8cf9-907d95c49114',
#                         [{"name": "AAPL", "type": "scatter", "x": ["2012-01-12", "2012-01-13", "2012-01-17", "2012-01-18", "2012-01-19", "2012-01-20", "2012-01-23", "2012-01-24", "2012-01-25", "2012-01-26", "2012-01-27", "2012-01-30", "2012-01-31", "2012-02-01", "2012-02-02", "2012-02-03", "2012-02-06", "2012-02-07", "2012-02-08", "2012-02-09", "2012-02-10", "2012-02-13", "2012-02-14", "2012-02-15", "2012-02-16", "2012-02-17", "2012-02-21", "2012-02-22", "2012-02-23", "2012-02-24", "2012-02-27", "2012-02-28", "2012-02-29", "2012-03-01", "2012-03-02", "2012-03-05", "2012-03-06", "2012-03-07", "2012-03-08", "2012-03-09", "2012-03-12", "2012-03-13", "2012-03-14", "2012-03-15", "2012-03-16", "2012-03-19", "2012-03-20", "2012-03-21", "2012-03-22", "2012-03-23", "2012-03-26", "2012-03-27", "2012-03-28", "2012-03-29", "2012-03-30", "2012-04-02", "2012-04-03", "2012-04-04", "2012-04-05", "2012-04-09", "2012-04-10", "2012-04-11", "2012-04-12", "2012-04-13", "2012-04-16", "2012-04-17", "2012-04-18", "2012-04-19", "2012-04-20", "2012-04-23", "2012-04-24", "2012-04-25", "2012-04-26", "2012-04-27", "2012-04-30", "2012-05-01", "2012-05-02", "2012-05-03", "2012-05-04", "2012-05-07", "2012-05-08", "2012-05-09", "2012-05-10", "2012-05-11", "2012-05-14", "2012-05-15", "2012-05-16", "2012-05-17", "2012-05-18", "2012-05-21", "2012-05-22", "2012-05-23", "2012-05-24", "2012-05-25", "2012-05-29", "2012-05-30", "2012-05-31", "2012-06-01", "2012-06-04", "2012-06-05", "2012-06-06", "2012-06-07", "2012-06-08", "2012-06-11", "2012-06-12", "2012-06-13", "2012-06-14", "2012-06-15", "2012-06-18", "2012-06-19", "2012-06-20", "2012-06-21", "2012-06-22", "2012-06-25", "2012-06-26", "2012-06-27", "2012-06-28", "2012-06-29", "2012-07-02", "2012-07-03", "2012-07-05", "2012-07-06", "2012-07-09", "2012-07-10", "2012-07-11", "2012-07-12", "2012-07-13", "2012-07-16", "2012-07-17", "2012-07-18", "2012-07-19", "2012-07-20", "2012-07-23", "2012-07-24", "2012-07-25", "2012-07-26", "2012-07-27", "2012-07-30", "2012-07-31", "2012-08-01", "2012-08-02", "2012-08-03", "2012-08-06", "2012-08-07", "2012-08-08", "2012-08-09", "2012-08-10", "2012-08-13", "2012-08-14", "2012-08-15", "2012-08-16", "2012-08-17", "2012-08-20", "2012-08-21", "2012-08-22", "2012-08-23", "2012-08-24", "2012-08-27", "2012-08-28", "2012-08-29", "2012-08-30", "2012-08-31", "2012-09-04", "2012-09-05", "2012-09-06", "2012-09-07", "2012-09-10", "2012-09-11", "2012-09-12", "2012-09-13", "2012-09-14", "2012-09-17", "2012-09-18", "2012-09-19", "2012-09-20", "2012-09-21", "2012-09-24", "2012-09-25", "2012-09-26", "2012-09-27", "2012-09-28", "2012-10-01", "2012-10-02", "2012-10-03", "2012-10-04", "2012-10-05", "2012-10-08", "2012-10-09", "2012-10-10", "2012-10-11", "2012-10-12", "2012-10-15", "2012-10-16", "2012-10-17", "2012-10-18", "2012-10-19", "2012-10-22", "2012-10-23", "2012-10-24", "2012-10-25", "2012-10-26", "2012-10-31", "2012-11-01", "2012-11-02", "2012-11-05", "2012-11-06", "2012-11-07", "2012-11-08", "2012-11-09", "2012-11-12", "2012-11-13", "2012-11-14", "2012-11-15", "2012-11-16", "2012-11-19", "2012-11-20", "2012-11-21", "2012-11-23", "2012-11-26", "2012-11-27", "2012-11-28", "2012-11-29", "2012-11-30", "2012-12-03", "2012-12-04", "2012-12-05", "2012-12-06", "2012-12-07", "2012-12-10", "2012-12-11", "2012-12-12", "2012-12-13", "2012-12-14", "2012-12-17", "2012-12-18", "2012-12-19", "2012-12-20", "2012-12-21", "2012-12-24", "2012-12-26", "2012-12-27", "2012-12-28", "2012-12-31", "2013-01-02", "2013-01-03", "2013-01-04", "2013-01-07", "2013-01-08", "2013-01-09", "2013-01-10", "2013-01-11", "2013-01-14", "2013-01-15", "2013-01-16", "2013-01-17", "2013-01-18", "2013-01-22", "2013-01-23", "2013-01-24", "2013-01-25", "2013-01-28", "2013-01-29", "2013-01-30", "2013-01-31", "2013-02-01", "2013-02-04", "2013-02-05", "2013-02-06", "2013-02-07", "2013-02-08", "2013-02-11", "2013-02-12", "2013-02-13", "2013-02-14", "2013-02-15", "2013-02-19", "2013-02-20", "2013-02-21", "2013-02-22", "2013-02-25", "2013-02-26", ...

# %% [markdown]
# # TASK #3: UNERSTAND THE CONCEPT OF ASSET ALLOCATION

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=17SLLaxLeP6vlXH6MltEQMFNbt5u-J6iK)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1qLML-ejBIKR8Bv8aeItfNaJuhq5GzvJ5)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1iR3WYvU9SYVRqhKwR91x0AsE5sGQtFhz)

# %% [markdown]
# **MINI CHALLENGE #2:**
# - **What is the common advice that financial advisors generally give to retired seniors when it comes to asset allocations?**

# %% [markdown]
# # TASK #4: PERFORM RANDOM ASSET ALLOCATION AND CALCULATE PORTFOLIO DAILY RETURN

# %%
np.random.seed()
weights = np.random.random(9)
weights= weights/np.sum(weights)
weights
# Out:
# array([0.14226926, 0.09661651, 0.22788974, 0.0183224 , 0.02914521,
#        0.19273948, 0.07149697, 0.2152255 , 0.00629494])

# %%
# Normalize the stock avalues 
df_portfolio = data_normalize(stock_df)
df_portfolio
# Out:
#             Date      AAPL        BA  ...       TSLA      GOOG     sp500
# 0     2012-01-12  1.000000  1.000000  ...   1.000000  1.000000  1.000000
# 1     2012-01-13  0.996251  0.987949  ...   0.806726  0.992615  0.995052
# 2     2012-01-17  1.007855  0.996424  ...   0.941593  0.998317  0.998587
# 3     2012-01-18  1.018320  0.994040  ...   0.949027  1.005193  1.009680
# 4     2012-01-19  1.015093  1.000662  ...   0.947257  1.015771  1.014666
# ...          ...       ...       ...  ...        ...       ...       ...
# 2154  2020-08-05  7.313297  2.308039  ...  52.567080  4.698347  2.568715
# 2155  2020-08-06  7.568452  2.280493  ...  52.728494  4.782805  2.585226
# 2156  2020-08-07  7.383066  2.251622  ...  51.423361  4.764919  2.586862
# 2157  2020-08-10  7.490377  2.375977  ...  50.214865  4.770052  2.593956
# 2158  2020-08-11  7.267614  2.385512  ...  48.650974  4.719740  2.573284
#
# [2159 rows x 10 columns]

# %%
for counter,stock in enumerate(df_portfolio.columns[1:]):
  df_portfolio[stock] = weights[counter] * df_portfolio[stock] * 1000000
df_portfolio
# Out:
#             Date          AAPL  ...          GOOG         sp500
# 0     2012-01-12  1.422693e+05  ...  2.152255e+05   6294.937125
# 1     2012-01-13  1.417358e+05  ...  2.136360e+05   6263.790262
# 2     2012-01-17  1.433868e+05  ...  2.148632e+05   6286.045224
# 3     2012-01-18  1.448757e+05  ...  2.163433e+05   6355.870168
# 4     2012-01-19  1.444165e+05  ...  2.186198e+05   6387.259630
# ...          ...           ...  ...           ...           ...
# 2154  2020-08-05  1.040457e+06  ...  1.011204e+06  16169.898141
# 2155  2020-08-06  1.076758e+06  ...  1.029382e+06  16273.833321
# 2156  2020-08-07  1.050383e+06  ...  1.025532e+06  16284.135137
# 2157  2020-08-10  1.065650e+06  ...  1.026637e+06  16328.789793
# 2158  2020-08-11  1.033958e+06  ...  1.015808e+06  16198.663506
#
# [2159 rows x 10 columns]

# %%
df_portfolio['Daily_Worth'] = df_portfolio[df_portfolio != 'Date'].sum(axis = 1)
df_portfolio
# Out:
#             Date          AAPL  ...         sp500   Daily_Worth
# 0     2012-01-12  1.422693e+05  ...   6294.937125  1.000000e+06
# 1     2012-01-13  1.417358e+05  ...   6263.790262  9.817457e+05
# 2     2012-01-17  1.433868e+05  ...   6286.045224  9.977519e+05
# 3     2012-01-18  1.448757e+05  ...   6355.870168  1.004853e+06
# 4     2012-01-19  1.444165e+05  ...   6387.259630  1.008245e+06
# ...          ...           ...  ...           ...           ...
# 2154  2020-08-05  1.040457e+06  ...  16169.898141  6.965192e+06
# 2155  2020-08-06  1.076758e+06  ...  16273.833321  7.035230e+06
# 2156  2020-08-07  1.050383e+06  ...  16284.135137  6.900365e+06
# 2157  2020-08-10  1.065650e+06  ...  16328.789793  6.846810e+06
# 2158  2020-08-11  1.033958e+06  ...  16198.663506  6.681476e+06
#
# [2159 rows x 11 columns]

# %%
# Calculating daily percentage returns
df_portfolio['Daily % Returns'] = 0.0000
for i in range(1,len(df_portfolio)):
  df_portfolio['Daily % Returns'][i] = (( df_portfolio['Daily_Worth'][i] - df_portfolio['Daily_Worth'][i-1]) / df_portfolio['Daily_Worth'][i-1]) * 100
df_portfolio
# Out:
#             Date          AAPL  ...   Daily_Worth  Daily % Returns
# 0     2012-01-12  1.422693e+05  ...  1.000000e+06         0.000000
# 1     2012-01-13  1.417358e+05  ...  9.817457e+05        -1.825429
# 2     2012-01-17  1.433868e+05  ...  9.977519e+05         1.630376
# 3     2012-01-18  1.448757e+05  ...  1.004853e+06         0.711743
# 4     2012-01-19  1.444165e+05  ...  1.008245e+06         0.337513
# ...          ...           ...  ...           ...              ...
# 2154  2020-08-05  1.040457e+06  ...  6.965192e+06         0.373283
# 2155  2020-08-06  1.076758e+06  ...  7.035230e+06         1.005539
# 2156  2020-08-07  1.050383e+06  ...  6.900365e+06        -1.916983
# 2157  2020-08-10  1.065650e+06  ...  6.846810e+06        -0.776123
# 2158  2020-08-11  1.033958e+06  ...  6.681476e+06        -2.414768
#
# [2159 rows x 12 columns]

# %% [markdown]
# **MINI CHALLENGE #3:**
# - **Try at least 3 another random weights allocation and rerun the code.**
# - **Compare the final portfolio value on Aug 11th, 2020 to its initial value ($1M) on January 12th, 2012. Do you notice a big difference? Comment on your answer.**

# %% [markdown]
# # TASK #5: PORTFOLIO ALLOCATION - DAILY RETURN/WORTH CALCULATION (FUNCTION)

# %%
# Lets assume we have $1,000,000 to be invested and we will allocate this fund based on the weights of the stocks
# We will create a function that takes in the stock prices along with the weights and return:
# (1) Daily value of each individual securuty in $ over the specified time period
# (2) Overall daily worth of the entire portfolio 
# (3) Daily return 

def portfolio_allocation(df, weights):
  df_portfolioalloc = df.copy()
  df_portfolioalloc = data_normalize(df_portfolioalloc)

# Calculating total for each stock-for each day based on the weight and assuming total investment of $1000000
  for counter , stock in enumerate(df_portfolioalloc.columns[1:]):
    df_portfolioalloc[stock] = df_portfolioalloc[stock] * weights[counter]
    df_portfolioalloc[stock] = df_portfolioalloc[stock] * 1000000

# Creating a new column to calculate the daily return for each day
  df_portfolioalloc['Total Daily Returns'] = df_portfolioalloc[df_portfolioalloc != 'Date'].sum(axis = 1)

#Creating another column to calculate the total percentage of daily returns for each day
  df_portfolioalloc['Daily % Returns'] = 0.000
  for i in range(1, len(df_portfolioalloc)):
    df_portfolioalloc['Daily % Returns'][i] = ( (df_portfolioalloc['Total Daily Returns'][i] - df_portfolioalloc['Total Daily Returns'][i-1]) / df_portfolioalloc['Total Daily Returns'][i-1]) * 100
  
  df_portfolioalloc['Daily % Returns'][0] = 0 
  return df_portfolioalloc

# %% [markdown]
# **MINI CHALLENGE #4:**
# - **Call the function and ensure that the results make sense**

# %%
df_portfolio = portfolio_allocation(stock_df,weights)
df_portfolio
# Out:
#             Date          AAPL  ...  Total Daily Returns  Daily % Returns
# 0     2012-01-12  1.422693e+05  ...         1.000000e+06         0.000000
# 1     2012-01-13  1.417358e+05  ...         9.817457e+05        -1.825429
# 2     2012-01-17  1.433868e+05  ...         9.977519e+05         1.630376
# 3     2012-01-18  1.448757e+05  ...         1.004853e+06         0.711743
# 4     2012-01-19  1.444165e+05  ...         1.008245e+06         0.337513
# ...          ...           ...  ...                  ...              ...
# 2154  2020-08-05  1.040457e+06  ...         6.965192e+06         0.373283
# 2155  2020-08-06  1.076758e+06  ...         7.035230e+06         1.005539
# 2156  2020-08-07  1.050383e+06  ...         6.900365e+06        -1.916983
# 2157  2020-08-10  1.065650e+06  ...         6.846810e+06        -0.776123
# 2158  2020-08-11  1.033958e+06  ...         6.681476e+06        -2.414768
#
# [2159 rows x 12 columns]

# %% [markdown]
# # TASK #6: PERFORM PORTFOLIO DATA VISUALIZATION

# %%
# Plot the portfolio daily return
df_portfolio.columns
# Out:
# Index(['Date', 'AAPL', 'BA', 'T', 'MGM', 'AMZN', 'IBM', 'TSLA', 'GOOG',
#        'sp500', 'Total Daily Returns', 'Daily % Returns'],
#       dtype='object')

# %%
fig = px.line(x=df_portfolio['Date'],y=df_portfolio['Daily % Returns'],title='Daily Returns 2012 - 2020')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="36efd4d4-3e72-46e4-857f-0848fc74ed33" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("36efd4d4-3e72-46e4-857f-0848fc74ed33")) {
#                     Plotly.newPlot(
#                         '36efd4d4-3e72-46e4-857f-0848fc74ed33',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2012-01-12", "2012-01-13", "2012-01-17", "2012-01-18", "2012-01-19", "2012-01-20", "2012-01-23", "2012-01-24", "2012-01-25", "2012-01-26", "2012-01-27", "2012-01-30", "2012-01-31", "2012-02-01", "2012-02-02", "2012-02-03", "2012-02-06", "2012-02-07", "2012-02-08", "2012-02-09", "2012-02-10", "2012-02-13", "2012-02-14", "2012-02-15", "2012-02-16", "2012-02-17", "2012-02-21", "2012-02-22", "2012-02-23", "2012-02-24", "2012-02-27", "2012-02-28", "2012-02-29", "2012-03-01", "2012-03-02", "2012-03-05", "2012-03-06", "2012-03-07", "2012-03-08", "2012-03-09", "2012-03-12", "2012-03-13", "2012-03-14", "2012-03-15", "2012-03-16", "2012-03-19", "2012-03-20", "2012-03-21", "2012-03-22", "2012-03-23", "2012-03-26", "2012-03-27", "2012-03-28", "2012-03-29", "2012-03-30", "2012-04-02", "2012-04-03", "2012-04-04", "2012-04-05", "2012-04-09", "2012-04-10", "2012-04-11", "2012-04-12", "2012-04-13", "2012-04-16", "2012-04-17", "2012-04-18", "2012-04-19", "2012-04-20", "2012-04-23", "2012-04-24", "2012-04-25", "2012-04-26", "2012-04-27", "2012-04-30", "2012-05-01", "2012-05-02", "2012-05-03", "2012-05-04", "2012-05-07", "2012-05-08", "2012-05-09", "2012-05-10", "2012-05-11", "2012-05-14", "2012-05-15", "2012-05-16", "2012-05-17", "2012-05-18", "2012-05-21", "2012-05-22", "2012-05-23", "2012-05-24", "2012-05-25", "2012-05-29", "2012-05-30", "2012-05-31", "2012-06-01", "2012-06-04", "2012-06-05", "2012-06-06", "2012-06-07", "2012-06-08", "2012-06-11", "2012-06-12", "2012-06-13", "2012-06-14", "2012-06-15", "2012-06-18", "2012-06-19", "2012-06-20", "2012-06-21", "2012-06-22", "2012-06-25", "2012-06-26", "2012-06-27", "2012-06-28", "2012-06-29", "2012-07-02", "2012-07-03", "2012-07-05", "2012-07-06", "2012-07-09", "2012-07-10", "2012-07-11", "2012-07-12", "2012-07-13", "2012-07-16", "2012-07-17", "2012-07-18", "2012-07-19", "2012-07-20", "2012-07-23", "2012-07-24", "2012-07-25", "2012-07-26", "2012-07-27", "2012-07-30", "2012-07-31", "2012-08-01", "2012-08-02", "2012-08-03", "2012-08-06", "2012-08-07", "2012-08-08", "2012-08-09", "2012-08-10", "2012-08-13", "2012-08-14", "2012-08-15", "2012-08-16", "2012-08-17", "2012-08-20", "2012-08-21", "2012-08-22", "2012-08-23", "2012-08-24", "2012-08-27", "2012-08-28", "2012-08-29", "2012-08-30", "2012-08-31", "2012-09-04", "2012-09-05", "2012-09-06", "2012-09-07", "2012-09-10", "2012-09-11", "2012-09-12", "2012-09-13", "2012-09-14", "2012-09-17", "2012-09-18", "2012-09-19", "2012-09-20", "2012-09-21", "2012-09-24", "2012-09-25", "2012-09-26", "2012-09-27", "2012-09-28", "2012-10-01", "2012-10-02", "2012-10-03", "2012-10-04", "2012-10-05", "2012-10-08", "2012-10-09", "2012-10-10", "2012-10-11", "2012-10-12", "2012-10-15", "2012-10-16", "2012-10-17", "2012-10-18", "2012-10-19", "2012-10-22", "2012-10-23", "2012-10-24", "2012-10-25", "2012-10-26", "2012-10-31", "2012-11-01", "2012-11-02", "2012-11-05", "2012-11-06", "2012-11-07", "2012-11-08", "2012-11-09", "2012-11-12", "2012-11-13", "2012-11-14", "2012-11-15", "2012-11-16", "2012-11-19", "2012-11-20", "2012-11-21", "2012-11-23", "2012-11-26", "2012-11-27", "2012-11-28", "2012-11-29", "2012-11-30", "2012-12-03", "2012-12-04", "2012-12-05", "2012-12-06", "2012-12-07", "2012-12-10", "2012-12-11", "2012-12-12", "2012-12-13", "2012-12-14", "2012-12-17", "2012-12-18", "2012-12-19", "2012-12-20", "2012-12-21", "2012-12-24", "2012-12-26", "2012-12-27", "2012-12-28", "2012-12-31", "2013-01-02", "2013-01-03", "2013-01-04", "2013-01-07", "2013-01-08", "2013-01-09", "2013-01-10", "2013-01-11", "2013-01-14", "2013-01-15", "2013-01-16", "2013-01-17", "2013-01-18", "2013-01-22", "2013-01-23", "2013-01-24", "2013-01-25", "2013-01-28", "2013-01-29", "2013-01-30", "2013-01-31", "2013-02-01", "2013-02-04", "2013-02-05", "2013-02-06", "2013-02- ...

# %%
# Plot all stocks (normalized)
plot_DataRa(df_portfolio.drop(['Total Daily Returns', 'Daily % Returns'],axis=1),'Normalized Stock')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3a707dc6-99af-4d3d-a628-f2886de593ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3a707dc6-99af-4d3d-a628-f2886de593ad")) {
#                     Plotly.newPlot(
#                         '3a707dc6-99af-4d3d-a628-f2886de593ad',
#                         [{"name": "AAPL", "type": "scatter", "x": ["2012-01-12", "2012-01-13", "2012-01-17", "2012-01-18", "2012-01-19", "2012-01-20", "2012-01-23", "2012-01-24", "2012-01-25", "2012-01-26", "2012-01-27", "2012-01-30", "2012-01-31", "2012-02-01", "2012-02-02", "2012-02-03", "2012-02-06", "2012-02-07", "2012-02-08", "2012-02-09", "2012-02-10", "2012-02-13", "2012-02-14", "2012-02-15", "2012-02-16", "2012-02-17", "2012-02-21", "2012-02-22", "2012-02-23", "2012-02-24", "2012-02-27", "2012-02-28", "2012-02-29", "2012-03-01", "2012-03-02", "2012-03-05", "2012-03-06", "2012-03-07", "2012-03-08", "2012-03-09", "2012-03-12", "2012-03-13", "2012-03-14", "2012-03-15", "2012-03-16", "2012-03-19", "2012-03-20", "2012-03-21", "2012-03-22", "2012-03-23", "2012-03-26", "2012-03-27", "2012-03-28", "2012-03-29", "2012-03-30", "2012-04-02", "2012-04-03", "2012-04-04", "2012-04-05", "2012-04-09", "2012-04-10", "2012-04-11", "2012-04-12", "2012-04-13", "2012-04-16", "2012-04-17", "2012-04-18", "2012-04-19", "2012-04-20", "2012-04-23", "2012-04-24", "2012-04-25", "2012-04-26", "2012-04-27", "2012-04-30", "2012-05-01", "2012-05-02", "2012-05-03", "2012-05-04", "2012-05-07", "2012-05-08", "2012-05-09", "2012-05-10", "2012-05-11", "2012-05-14", "2012-05-15", "2012-05-16", "2012-05-17", "2012-05-18", "2012-05-21", "2012-05-22", "2012-05-23", "2012-05-24", "2012-05-25", "2012-05-29", "2012-05-30", "2012-05-31", "2012-06-01", "2012-06-04", "2012-06-05", "2012-06-06", "2012-06-07", "2012-06-08", "2012-06-11", "2012-06-12", "2012-06-13", "2012-06-14", "2012-06-15", "2012-06-18", "2012-06-19", "2012-06-20", "2012-06-21", "2012-06-22", "2012-06-25", "2012-06-26", "2012-06-27", "2012-06-28", "2012-06-29", "2012-07-02", "2012-07-03", "2012-07-05", "2012-07-06", "2012-07-09", "2012-07-10", "2012-07-11", "2012-07-12", "2012-07-13", "2012-07-16", "2012-07-17", "2012-07-18", "2012-07-19", "2012-07-20", "2012-07-23", "2012-07-24", "2012-07-25", "2012-07-26", "2012-07-27", "2012-07-30", "2012-07-31", "2012-08-01", "2012-08-02", "2012-08-03", "2012-08-06", "2012-08-07", "2012-08-08", "2012-08-09", "2012-08-10", "2012-08-13", "2012-08-14", "2012-08-15", "2012-08-16", "2012-08-17", "2012-08-20", "2012-08-21", "2012-08-22", "2012-08-23", "2012-08-24", "2012-08-27", "2012-08-28", "2012-08-29", "2012-08-30", "2012-08-31", "2012-09-04", "2012-09-05", "2012-09-06", "2012-09-07", "2012-09-10", "2012-09-11", "2012-09-12", "2012-09-13", "2012-09-14", "2012-09-17", "2012-09-18", "2012-09-19", "2012-09-20", "2012-09-21", "2012-09-24", "2012-09-25", "2012-09-26", "2012-09-27", "2012-09-28", "2012-10-01", "2012-10-02", "2012-10-03", "2012-10-04", "2012-10-05", "2012-10-08", "2012-10-09", "2012-10-10", "2012-10-11", "2012-10-12", "2012-10-15", "2012-10-16", "2012-10-17", "2012-10-18", "2012-10-19", "2012-10-22", "2012-10-23", "2012-10-24", "2012-10-25", "2012-10-26", "2012-10-31", "2012-11-01", "2012-11-02", "2012-11-05", "2012-11-06", "2012-11-07", "2012-11-08", "2012-11-09", "2012-11-12", "2012-11-13", "2012-11-14", "2012-11-15", "2012-11-16", "2012-11-19", "2012-11-20", "2012-11-21", "2012-11-23", "2012-11-26", "2012-11-27", "2012-11-28", "2012-11-29", "2012-11-30", "2012-12-03", "2012-12-04", "2012-12-05", "2012-12-06", "2012-12-07", "2012-12-10", "2012-12-11", "2012-12-12", "2012-12-13", "2012-12-14", "2012-12-17", "2012-12-18", "2012-12-19", "2012-12-20", "2012-12-21", "2012-12-24", "2012-12-26", "2012-12-27", "2012-12-28", "2012-12-31", "2013-01-02", "2013-01-03", "2013-01-04", "2013-01-07", "2013-01-08", "2013-01-09", "2013-01-10", "2013-01-11", "2013-01-14", "2013-01-15", "2013-01-16", "2013-01-17", "2013-01-18", "2013-01-22", "2013-01-23", "2013-01-24", "2013-01-25", "2013-01-28", "2013-01-29", "2013-01-30", "2013-01-31", "2013-02-01", "2013-02-04", "2013-02-05", "2013-02-06", "2013-02-07", "2013-02-08", "2013-02-11", "2013-02-12", "2013-02-13", "2013-02-14", "2013-02-15", "2013-02-19", "2013-02-20", "2013-02-21", "2013-02-22", "2013-02-25", "2013-02-26", ...

# %%
# Print out a histogram of daily returns
fig = px.histogram(df_portfolio,x=df_portfolio['Daily % Returns'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9149a1a4-9786-4fc4-9fe1-6b0dfa7eee42" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9149a1a4-9786-4fc4-9fe1-6b0dfa7eee42")) {
#                     Plotly.newPlot(
#                         '9149a1a4-9786-4fc4-9fe1-6b0dfa7eee42',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "Daily % Returns=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [0.0, -1.8254288363175002, 1.6303760018403108, 0.7117427433564005, 0.33751251626469847, -1.2780391333032965, 0.33555828607725857, -0.2571923736842905, 0.7769527321323066, -0.5102441545448939, 0.2765237365180959, 0.41834864429749885, 0.16114951024279106, 0.29557618374174965, 0.35267162247864225, 1.4143974313082275, 0.4202994084351726, 0.11630901670602399, 0.48260133869721655, 0.8202307107365615, -0.7999737608594596, 0.8476954444571287, 0.5982143729304075, -0.702954983676448, 0.48062027998717693, 0.19975231689424938, 0.8068248521514385, -0.3608280575348028, 0.6500111548372631, 0.04861236155356018, -0.10981611547703318, 0.9379046276356471, -0.08757973786153364, 0.5866597423144043, 0.14649469882842844, -0.5277647529140518, -1.295712567309755, 0.44212816810545263, 0.8454490248919304, 0.314615521165087, 0.8855858501858275, 1.5501176243795634, 0.41908289181291836, 0.3618763904552451, 0.10414345863065917, 0.7164238804334047, 0.12605432108310674, 0.18813924097361082, -0.2329351389102899, -0.34501693548795204, 1.9940847709216947, 0.10651776644586995, -0.023025855757467052, -0.5731043745537443, -0.5190862570284841, 0.8611802452428781, 0.48478729159256606, -1.5113052943886474, -0.39599069408019166, -0.7080074942670592, -1.4610254591537615, 0.8314397334930109, 1.2526627627261462, -1.8370512255145026, -1.7103148488747961, 1.9233188191227282, -0.8287624797629644, -0.9219471428723276, -0.4574565833276363, -0.7185159965006799, 0.7173587710599987, 3.01338718499176, 0.9828962799654442, 0.5700578557209623, -0.7650388820301115, 0.2767225081341955, 0.26746629982031916, -0.5229483684547879, -1.7155681393932876, 0.5697152060500356, -0.7233941404111685, -0.49132913805483014, 1.0415051185760138, -0.18853554144501508, -1.2033271848708502, -0.306094627877429, 0.18954534621835628, -1.4047360102441568, -1.0419162592237907, 2.3456084693956436, -0.33248852188644107, 0.6010012972357597, -0.36572122430395193, -0.9318276445042538, 1.3677137444225786, -0.7776484341207232, -0.35170726710905315, -2.151121842001587, 0.5482767208511475, -0.2359376404418973, 2.0542590614139695, -0.24276171903779964, 0.9758030699508422, -1.1774941171738242, 0.9790235715363418, -0.49427564201087504, 0.5148950379165549, 0.8203249208687199, 0.93852231888865, 0.5647710550755046, 0.16289881288592137, -2.0311175175498497, 0.931559702473516, -1.2848129978154454, -0.16766037493101663, 0.6762955528371388, -0.5476957308101776, 2.0230085490640635, 0.332647066570107, 0.5106643016730196, 0.4383677796492464, -1.211118687942314, 0.2526352576425546, -0.9478365438426886, -0.8440230799389554, -0.4882304659989761, 1.633741682962581, 0.22630959863090108, -0.30220791862197793, 0.6429820494555236, 1.1136985437057279, -0.42893448097739645, -0.372456593714891, -1.2737028783207136, -0.3198000448857663, 1.0829996561081539, 2.469712111988823, -0.13353986112240238, 0.6192478590036122, -0.8049790219738722, -0.42558222924174965, 1.4921306295318006, 0.52157306137653, 0.6226138622028083, -0.37290992223776964, -0.15437448468012416, 0.3670240780126672, 0.9804207389566534, -0.26221311100836875, -0.1375425552987312, 0.9738879246941975, 0.4340155863645908, 0.07935802544820542, -0.9706224376158294, 0.6318148684936087, -0.48678180171680435, 0.3957128820927648, -0.43161994114893937, 0.10377077445925033, 0.3707542465898088, -0.824375463805481, 0.3661444807978702, 0.08479646407947987, 0.025792354908922354, 1.805312956390844, 0.592683494361378, -1.061438029414551, 0.10424477931092462, 0.4246588428096438, 1.7465758040826938, 0.008841238733624888, 0.7224102248516828, 0.1152096226140065, 0.2050791429973155, -0.08079367640234109, 0.04798579120111792, 0.3137161379363063, -1.372243168083894, -0.14992068883060258, 0.9725535959260632, ...

# %% [markdown]
# **MINI CHALLENGE #5:**
# - **Plot the portfolio overall daily worth vs. time.**
# - **Rerun the code with various weights and visualize the final value.**

# %%
fig = px.line(x=df_portfolio['Date'], y = df_portfolio['Total Daily Returns'], title='Daily Worth Vs. Time')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8a2158c0-df4b-4fff-8a46-a272e140d076" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8a2158c0-df4b-4fff-8a46-a272e140d076")) {
#                     Plotly.newPlot(
#                         '8a2158c0-df4b-4fff-8a46-a272e140d076',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2012-01-12", "2012-01-13", "2012-01-17", "2012-01-18", "2012-01-19", "2012-01-20", "2012-01-23", "2012-01-24", "2012-01-25", "2012-01-26", "2012-01-27", "2012-01-30", "2012-01-31", "2012-02-01", "2012-02-02", "2012-02-03", "2012-02-06", "2012-02-07", "2012-02-08", "2012-02-09", "2012-02-10", "2012-02-13", "2012-02-14", "2012-02-15", "2012-02-16", "2012-02-17", "2012-02-21", "2012-02-22", "2012-02-23", "2012-02-24", "2012-02-27", "2012-02-28", "2012-02-29", "2012-03-01", "2012-03-02", "2012-03-05", "2012-03-06", "2012-03-07", "2012-03-08", "2012-03-09", "2012-03-12", "2012-03-13", "2012-03-14", "2012-03-15", "2012-03-16", "2012-03-19", "2012-03-20", "2012-03-21", "2012-03-22", "2012-03-23", "2012-03-26", "2012-03-27", "2012-03-28", "2012-03-29", "2012-03-30", "2012-04-02", "2012-04-03", "2012-04-04", "2012-04-05", "2012-04-09", "2012-04-10", "2012-04-11", "2012-04-12", "2012-04-13", "2012-04-16", "2012-04-17", "2012-04-18", "2012-04-19", "2012-04-20", "2012-04-23", "2012-04-24", "2012-04-25", "2012-04-26", "2012-04-27", "2012-04-30", "2012-05-01", "2012-05-02", "2012-05-03", "2012-05-04", "2012-05-07", "2012-05-08", "2012-05-09", "2012-05-10", "2012-05-11", "2012-05-14", "2012-05-15", "2012-05-16", "2012-05-17", "2012-05-18", "2012-05-21", "2012-05-22", "2012-05-23", "2012-05-24", "2012-05-25", "2012-05-29", "2012-05-30", "2012-05-31", "2012-06-01", "2012-06-04", "2012-06-05", "2012-06-06", "2012-06-07", "2012-06-08", "2012-06-11", "2012-06-12", "2012-06-13", "2012-06-14", "2012-06-15", "2012-06-18", "2012-06-19", "2012-06-20", "2012-06-21", "2012-06-22", "2012-06-25", "2012-06-26", "2012-06-27", "2012-06-28", "2012-06-29", "2012-07-02", "2012-07-03", "2012-07-05", "2012-07-06", "2012-07-09", "2012-07-10", "2012-07-11", "2012-07-12", "2012-07-13", "2012-07-16", "2012-07-17", "2012-07-18", "2012-07-19", "2012-07-20", "2012-07-23", "2012-07-24", "2012-07-25", "2012-07-26", "2012-07-27", "2012-07-30", "2012-07-31", "2012-08-01", "2012-08-02", "2012-08-03", "2012-08-06", "2012-08-07", "2012-08-08", "2012-08-09", "2012-08-10", "2012-08-13", "2012-08-14", "2012-08-15", "2012-08-16", "2012-08-17", "2012-08-20", "2012-08-21", "2012-08-22", "2012-08-23", "2012-08-24", "2012-08-27", "2012-08-28", "2012-08-29", "2012-08-30", "2012-08-31", "2012-09-04", "2012-09-05", "2012-09-06", "2012-09-07", "2012-09-10", "2012-09-11", "2012-09-12", "2012-09-13", "2012-09-14", "2012-09-17", "2012-09-18", "2012-09-19", "2012-09-20", "2012-09-21", "2012-09-24", "2012-09-25", "2012-09-26", "2012-09-27", "2012-09-28", "2012-10-01", "2012-10-02", "2012-10-03", "2012-10-04", "2012-10-05", "2012-10-08", "2012-10-09", "2012-10-10", "2012-10-11", "2012-10-12", "2012-10-15", "2012-10-16", "2012-10-17", "2012-10-18", "2012-10-19", "2012-10-22", "2012-10-23", "2012-10-24", "2012-10-25", "2012-10-26", "2012-10-31", "2012-11-01", "2012-11-02", "2012-11-05", "2012-11-06", "2012-11-07", "2012-11-08", "2012-11-09", "2012-11-12", "2012-11-13", "2012-11-14", "2012-11-15", "2012-11-16", "2012-11-19", "2012-11-20", "2012-11-21", "2012-11-23", "2012-11-26", "2012-11-27", "2012-11-28", "2012-11-29", "2012-11-30", "2012-12-03", "2012-12-04", "2012-12-05", "2012-12-06", "2012-12-07", "2012-12-10", "2012-12-11", "2012-12-12", "2012-12-13", "2012-12-14", "2012-12-17", "2012-12-18", "2012-12-19", "2012-12-20", "2012-12-21", "2012-12-24", "2012-12-26", "2012-12-27", "2012-12-28", "2012-12-31", "2013-01-02", "2013-01-03", "2013-01-04", "2013-01-07", "2013-01-08", "2013-01-09", "2013-01-10", "2013-01-11", "2013-01-14", "2013-01-15", "2013-01-16", "2013-01-17", "2013-01-18", "2013-01-22", "2013-01-23", "2013-01-24", "2013-01-25", "2013-01-28", "2013-01-29", "2013-01-30", "2013-01-31", "2013-02-01", "2013-02-04", "2013-02-05", "2013-02-06", "2013-02- ...

# %% [markdown]
# # TASK #7: UNDERSTAND PORTFOLIO STATISTICAL METRICS (CUMMULATIVE RETURN, AVERAGE DAILY RETURN, AND SHARPE RATIO)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1W_MNP2Qldn3ulrvXivOnjQg3NTf3hNCo)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=12e4Zgxv1FNviJYML88G6cTnlte0bts-4)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1QQLWpIJ8uXopJrV40YFKb5H-SxnmsRaj)

# %% [markdown]
# # TASK #8: CALCULATE PORTFOLIO STATISTICAL METRICS (CUMMULATIVE RETURN, AVERAGE DAILY RETURN, AND SHARPE RATIO)

# %%
df_portfolio
# Out:
#             Date          AAPL  ...  Total Daily Returns  Daily % Returns
# 0     2012-01-12  1.422693e+05  ...         1.000000e+06         0.000000
# 1     2012-01-13  1.417358e+05  ...         9.817457e+05        -1.825429
# 2     2012-01-17  1.433868e+05  ...         9.977519e+05         1.630376
# 3     2012-01-18  1.448757e+05  ...         1.004853e+06         0.711743
# 4     2012-01-19  1.444165e+05  ...         1.008245e+06         0.337513
# ...          ...           ...  ...                  ...              ...
# 2154  2020-08-05  1.040457e+06  ...         6.965192e+06         0.373283
# 2155  2020-08-06  1.076758e+06  ...         7.035230e+06         1.005539
# 2156  2020-08-07  1.050383e+06  ...         6.900365e+06        -1.916983
# 2157  2020-08-10  1.065650e+06  ...         6.846810e+06        -0.776123
# 2158  2020-08-11  1.033958e+06  ...         6.681476e+06        -2.414768
#
# [2159 rows x 12 columns]

# %%
df_portfolio['Total Daily Returns'][0]
# Out:
# 1000000.0

# %%
# Cummulative return of the portfolio (Note that we now look for the last net worth of the portfolio compared to it's start value)
cummulative_return = ( (df_portfolio['Total Daily Returns'][-1:] - df_portfolio['Total Daily Returns'][0] )/ df_portfolio['Total Daily Returns'][0]) * 100
print('Cummulative return is {} %'.format(cummulative_return.values[0]))
# Out:
# Cummulative return is 568.1475530670848 %

# %%
# Calculate the portfolio standard deviation
print('The Standard Deviation for the portfolio is {} '.format(df_portfolio['Daily % Returns'].std()))
# Out:
# The Standard Deviation for the portfolio is 1.498582340116603

# %%
# Calculate the average daily return 
print('The average daily return of the portfolio is :{} %'.format(df_portfolio['Daily % Returns'].mean()))
# Out:
# The average daily return of the portfolio is :0.09928724648113929 %

# %%
# Portfolio sharpe ratio
sharpe_ratio = (df_portfolio['Daily % Returns'].mean() / df_portfolio['Daily % Returns'].std() ) * np.sqrt(252)
print('Sharpe Ratio of the profile is {}'.format( sharpe_ratio))
# Out:
# Sharpe Ratio of the profile is 1.051751467439665

# %% [markdown]
# **MINI CHALLENGE #6:**
# - **Try at least 3 different random weights allocation, rerun the code and compare sharpe ratios, daily return and cummulative returns.**

# %% [markdown]
# 1. Cummulative return is 855.0541225672567 %
#
# The Standard Deviation for the portfolio is 1.8518480890822384
#
# Sharpe Ratio of the profile is 1.044976378807296
#
# 2.Cummulative return is 568.1475530670848 %
#
# The Standard Deviation for the portfolio is 1.498582340116603
#
# The average daily return of the portfolio is :0.09928724648113929 %
#
# Sharpe Ratio of the profile is 1.051751467439665

# %% [markdown]
# # **WELL DONE!**

# %% [markdown]
# # **MINI CHALLENGE SOLUTIONS**

# %% [markdown]
# **MINI CHALLENGE #1 SOLUTION:**
# - **Use Plotly express to visualize raw stock data and normalized ones**

# %%
# Function to normalize the prices based on the initial price
def normalize(df):
  x = df.copy()
  for i in x.columns[1:]:
    x[i] = x[i]/x[i][0]
  return x

# %%
# Function to plot interactive plot
def interactive_plot(df, title):
  fig = px.line(title = title)
  for i in df.columns[1:]:
    fig.add_scatter(x = df['Date'], y = df[i], name = i)
  fig.show()

# %%
# Plot interactive chart
interactive_plot(stocks_df, 'Prices')

# %%
# Plot normalized interactive chart
interactive_plot(normalize(stocks_df), 'Normalized Prices')

# %% [markdown]
# **MINI CHALLENGE #2 SOLUTION:**
# - **What is the common advice that financial advisors generally recommend to retired seniors when it comes to asset allocations?**

# %%
# The conventional wisdom is to subtract client's age from 100 to calculate the % of portolio that should be allocated to stocks
# For Example: If you're 30 years old, you should have 70% allocated to stocks
# If you are 75 years old, you should invest 25% in stocks (old retired seniors generally recommend a more stable low risk portfolio).

# %% [markdown]
# **MINI CHALLENGE #3 SOLUTION:**
# - **Try at least 3 another random weights allocation and rerun the code.**
# - **Compare the final portfolio value on Aug 11th, 2020 to its initial value ($1M) on January 12th, 2012. Do you notice a big difference? Comment on your answer.**

# %%
# remove the seed value of 101, run the code 3 times, and record the final portolio value on the last day (Aug 11th, 2020)
np.random.seed()

# Portfolio Value Run #1 = $6.383645e+06, weights = [0.01246531 0.23749173 0.18257962 0.03419922 0.08369018 0.23405306
 0.07120053 0.00824087 0.13607948]

# Portfolio Value Run #2 = $9.594104e+06, Weights = [0.13932903 0.04729773 0.15580758 0.03232255 0.0629491  0.15081605
 0.12206726 0.16938746 0.12002324]

# Portfolio Value Run #3 = 1.138105e+07, Weights = [0.17707261 0.06977804 0.02394314 0.1550952  0.11152213 0.12017452
 0.14296447 0.05729485 0.14215505]

# %% [markdown]
# **MINI CHALLENGE #4 SOLUTION:**
# - **Call the function and ensure that the results make sense**

# %%
# Call the function
df_portfolio = portfolio_allocation(stocks_df, weights)
df_portfolio

# %% [markdown]
# **MINI CHALLENGE #5 SOLUTION:**
# - **Plot the portfolio overall daily worth vs. time.**
# - **Rerun the code with various weights and visualize the final value.**

# %%
fig = px.line(x = df_portfolio.Date, y = df_portfolio['portfolio daily worth in $'], title= 'Portfolio Overall Value in $')
fig.show()

# %% [markdown]
# **MINI CHALLENGE #6 SOLUTION:**
# - **Try at least 3 different random weights allocation, rerun the code and compare sharpe ratios, daily return and cummulative returns.**

# %%
# Rerun the code with 3 random values and compare metrics
